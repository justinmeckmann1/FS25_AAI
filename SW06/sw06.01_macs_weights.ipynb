# %% [markdown]
# ![hslu_logo.png](img/hslu_logo.png)
#
# ## Week 6
#
# <hr style="border:1px solid black">
#
#
# # Exercise 1: CNN Complexity Analysis
# ---
# ---
# This excercise is to illustrate how to count MAC operations and trainable parameters in a CNN by hand.

# %% [markdown]
# ### Analyze the MNIST model architecture
#
# Given is the following CNN architecture with 2 CONV and 1 FC layer. Calculate the number of MACs and weights in these three layers to obtain the total numbers in the network.
#
# <img src="./img/MNIST_ref_architecture_param.png" alt="CNN Architecture" width="500px" />

# %%
##### Count MAC Operations & Trainable parameters (Weights)
## Init arrays
N_M = [0]
N_W = [0]

## CONV Layer 1
N_M.append(26*26*32*3*3*1)  # wieviele Pixel hat mein Outputfeature map --> Total # of MAC operations --> N_conv m = (E ⋅ F ⋅ M) ⋅ (R ⋅ S ⋅ C)
N_W.append(3*3*1*32+32)     # Total Number of train parameters (weights) N CONV w = (R ⋅ S ⋅ C) ⋅ M + M
# --> entspricht der Aufgabe 4

## CONV Layer 2
N_M.append(11*11*64*3*3*32)  # <---- ToDo
N_W.append()  # <---- ToDo

## FC Layer 1 (Fully Connected Layer)
N_M.append(5*5*64)  # <---- ToDo
N_W.append(0)  # <---- ToDo

## Print total numbers
print("# of MACs   : " + str(sum(N_M)))
print("# of Weihgts: " + str(sum(N_W)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 13
#       9 # --> entspricht der Aufgabe 4
#      10
#      11 ## CONV Layer 2
#      12 N_M.append(11*11*64*3*3*32)  # <---- ToDo
# ---> 13 N_W.append()  # <---- ToDo
#      15 ## FC Layer 1 (Fully Connected Layer)
#      16 N_M.append(5*5*64)  # <---- ToDo
#
# TypeError: append() takes exactly one argument (0 given)

# %% [markdown]
# ### Analyze the CIFAR model architecture
#
# Given is the following CNN architecture with 6 CONV and 2 FC layers. Calculate the number of MACs and weights in these eight layers to obtain the total numbers in the network.
#
# <img src="./img/CIFAR_ref_architecture.png" alt="CNN Architecture" width="1000px" />

# %%
##### Count MAC Operations & Trainable parameters (Weights)
## Init arrays
N_M = [0]
N_W = [0]

## CONV Layer 1
N_M.append(0)  # <---- ToDo
N_W.append(0)  # <---- ToDo

## CONV Layer 2
N_M.append(0)  # <---- ToDo
N_W.append(0)  # <---- ToDo

## CONV Layer 3
N_M.append(0)  # <---- ToDo
N_W.append(0)  # <---- ToDo

## CONV Layer 4
N_M.append(0)  # <---- ToDo
N_W.append(0)  # <---- ToDo

## CONV Layer 5
N_M.append(0)  # <---- ToDo
N_W.append(0)  # <---- ToDo

## CONV Layer 6
N_M.append(0)  # <---- ToDo
N_W.append(0)  # <---- ToDo

## FC Layer 1
N_M.append(0)  # <---- ToDo
N_W.append(0)  # <---- ToDo

## FC Layer 2
N_M.append(0)  # <---- ToDo
N_W.append(0)  # <---- ToDo

## Print total numbers
print("# of MACs   : " + str(sum(N_M)))
print("# of Weihgts: " + str(sum(N_W)))
