# %%
# train model 
# %run -m main_evo

# %%
# verify DNA 0 model on test dataset
# if not happy --> adjust training parameters

# %run -m evaluate_model best_model_dna_0
# Out:
# Evaluating model: best_model_dna_0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  activation_1 (Activation)   (None, 32, 32, 32)        0
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  activation_2 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
# ...

# %%
# %run -m plot_rank_func 18496 80 10000 80

# %%
# search space constraints: 
# max_mac 
# max_param

# %%
# 2D Ranking Function: 

# sigma_acc 
# mu_mac 
# sigma_mac 

# example: DNA 0 has accuracy 94.9% and mac 2440000, we want 99% accuracy and 300000 mac
# %run -m plot_rank_func 2440000 94.9 300000 99

# %%
# %run -m run_analysis 5 0.78
# Out:
# ------------------------------------------------------------------------------
# Best networks by accuracy only:
# 1: DNA 0: Acc=0.7873333096504211 with 0 MACs and 0 parameters, Generation 0 with 0 mutations
# 2: DNA 8: Acc=0.7363333106040955 with 3261696 MACs and 306602 parameters, Generation 1 with 1 mutations
# 3: DNA 21: Acc=0.7036666870117188 with 3123456 MACs and 306602 parameters, Generation 4 with 1 mutations
# 4: DNA 13: Acc=0.70333331823349 with 3261696 MACs and 306602 parameters, Generation 2 with 2 mutations
# 5: DNA 14: Acc=0.7020000219345093 with 3257832 MACs and 302710 parameters, Generation 2 with 2 mutations
# ------------------------------------------------------------------------------
# Best networks by number of MACs only:
# DNA 0: Acc=0.7873333096504211 with 0 MACs and 0 parameters, Generation 0 with 0 mutations
# DNA 25: Acc=0.4046666622161865 with 455424 MACs and 306090 parameters, Generation 4 with 5 mutations
# ...

# %%
# %run -m run_analysis NUM_DNA 4

# %%
# plot scatter
# %run -m plot_acc_macs NUM_GEN MIN_ACC
# Out:
# Total # of DNAs created: 27
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# File c:\Users\justi\anaconda3\envs\FS25_AAI\lib\runpy.py:206, in run_module(mod_name, init_globals, run_name, alter_sys)
#     204     run_name = mod_name
#     205 if alter_sys:
# --> 206     return _run_module_code(code, init_globals, run_name, mod_spec)
#     207 else:
#     208     # Leave the sys module alone
#     209     return _run_code(code, {}, init_globals, run_name, mod_spec)
#
# File c:\Users\justi\anaconda3\envs\FS25_AAI\lib\runpy.py:96, in _run_module_code(code, init_globals, mod_name, mod_spec, pkg_name, script_name)
#      94 with _TempModule(mod_name) as temp_module, _ModifiedArgv0(fname):
#      95     mod_globals = temp_module.module.__dict__
# ---> 96     _run_code(code, mod_globals, init_globals,
#      97               mod_name, mod_spec, pkg_name, script_name)
# ...

# %%
# %run -m visualize_cnn_arch DNA_NUM

# %%
# %run -m evaluate_model best_model_dna_3

# %%
# %run -m python export_model best_model_dna_3_retrnd #set dna number
