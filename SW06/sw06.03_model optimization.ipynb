# %%
# train model 
# %run -m main_evo
# Out:
# Running EA... Press Ctrl+C to exit.
# Device list for tensorflow:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3873507987741171440
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 46473413376
# locality {
#   bus_id: 1
# }
# incarnation: 16300138889452423105
# physical_device_desc: "device: 0, name: DML, pci bus id: <undefined>"
# xla_global_id: -1
# ]
# -------------------------------------------------------
# 2025-04-02 10:52:18
# -------------------------------------------------------
# Maximum MACs allowed: 40000000 - Maximum parameters allowed: 1000000
# x_train shape: (30000, 32, 32, 3, 1)
# 30000 train samples
# Balance:  {0: 2993, 1: 2911, 2: 3013, 3: 2986, 4: 3020, 5: 3032, 6: 3035, 7: 2986, 8: 3057, 9: 2967}
# 3000 val samples
# Balance:  {0: 283, 1: 311, 2: 308, 3: 303, 4: 302, 5: 305, 6: 298, 7: 321, 8: 282, 9: 287}
# 10000 test samples
# Balance:  {0: 1000, 1: 1000, 2: 1000, 3: 1000, 4: 1000, 5: 1000, 6: 1000, 7: 1000, 8: 1000, 9: 1000}
# Usecase CIFAR - data prepared
# Usecase CIFAR - Architecture Kaggle loaded
# >>>>>>>> Basic DNA created
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  activation_1 (Activation)   (None, 32, 32, 32)        0
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  activation_2 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  activation_3 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_3 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  activation_4 (Activation)   (None, 8, 8, 128)         0
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  activation_5 (Activation)   (None, 8, 8, 128)         0
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  activation_6 (Activation)   (None, 128)               0
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
#  softmax (Softmax)           (None, 10)                0
#
# =================================================================
# Total params: 552,362
# Trainable params: 551,466
# Non-trainable params: 896
# _________________________________________________________________
# Conv2D layer detected - MAC: 884736
# Other layer detected: Activation
# Other layer detected: BatchNormalization
# Conv2D layer detected - MAC: 9437184
# Other layer detected: Activation
# Other layer detected: BatchNormalization
# Other layer detected: MaxPooling2D
# Other layer detected: Dropout
# Conv2D layer detected - MAC: 4718592
# Other layer detected: Activation
# Other layer detected: BatchNormalization
# Conv2D layer detected - MAC: 9437184
# Other layer detected: Activation
# Other layer detected: BatchNormalization
# Other layer detected: MaxPooling2D
# Other layer detected: Dropout
# Conv2D layer detected - MAC: 4718592
# Other layer detected: Activation
# Other layer detected: BatchNormalization
# Conv2D layer detected - MAC: 9437184
# Other layer detected: Activation
# Other layer detected: BatchNormalization
# Other layer detected: MaxPooling2D
# Other layer detected: Dropout
# Other layer detected: Flatten
# Dense layer detected - MAC: 262144
# Other layer detected: Activation
# Other layer detected: Dropout
# Dense layer detected - MAC: 1280
# Other layer detected: Softmax
# Total amount of MAC: 38896896
# Network MAC is in allowed range. It uses 97.24%
# DNA has 552362 parameters
# Network parameter count is in allowed range. It uses 55.24%
# DNA 0 has hash 195beb7604a4be91a077e5ec1e42aa7ac6c1e12906e175a5a6f41fd763789bda
# DNA 1 has hash fc2db470ac1ba820013afe274bcda89c063923dab77c041ef42a76ffdf929462
# DNA 2 has hash 9cbab5b0af35c49e774c61fd0fdd626cb473ddba5277851757fa356055c179c8
# DNA 3 has hash e9987d7900177044b9d52c1fc61ea1d85120eac68cb9fa1e1a805aa11715d5cb
# DNA 4 has hash eeb2ba3193a5ba0aeaafb3cf392b3fda747378f675897063f70e7f937a1de55e
# DNA 5 has hash b2811cc04d8e2e576e044dce5e4d81379c5afc1df6ce4225fa47d0957b86540a
# DNA 6 has hash 773b68ec0e68dd35667efd1d0e2cc5464682ac0c2aca83d418a44d95c0ce47fc
# DNA 7 has hash 870d5135790532af554987219f154422318fefc4fc5ae47f199c9a8a5d699f8c
# DNA 8 has hash e7655514737a4992beec9c074fecb5fd0cb22e63db80eb6b392ae9752320f3a7
# DNA 9 has hash b401a71e21837461f1817af34e490dd9adfec1813176a05b23f3ae3f4ecdaca2
# >>>>>>>> Initial population created. Population count: 10. Starting initial training.
# Training DNA number: 1
# Epoch 1/12
# 150/150 - 2s - loss: 1.9823 - categorical_accuracy: 0.3223 - val_loss: 2.5911 - val_categorical_accuracy: 0.1547 - lr: 0.0040 - 2s/epoch - 12ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 1.4511 - categorical_accuracy: 0.4716 - val_loss: 2.5178 - val_categorical_accuracy: 0.2360 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 1.2528 - categorical_accuracy: 0.5506 - val_loss: 1.3956 - val_categorical_accuracy: 0.5310 - lr: 0.0040 - 986ms/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 1.1019 - categorical_accuracy: 0.6150 - val_loss: 1.0516 - val_categorical_accuracy: 0.6330 - lr: 0.0040 - 975ms/epoch - 6ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 1.0022 - categorical_accuracy: 0.6528 - val_loss: 1.2152 - val_categorical_accuracy: 0.6073 - lr: 0.0040 - 916ms/epoch - 6ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 0.8581 - categorical_accuracy: 0.7006 - val_loss: 0.8286 - val_categorical_accuracy: 0.7113 - lr: 0.0020 - 973ms/epoch - 6ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 0.8059 - categorical_accuracy: 0.7196 - val_loss: 0.7972 - val_categorical_accuracy: 0.7230 - lr: 0.0020 - 989ms/epoch - 7ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 0.7650 - categorical_accuracy: 0.7391 - val_loss: 0.8628 - val_categorical_accuracy: 0.7210 - lr: 0.0020 - 922ms/epoch - 6ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 0.6861 - categorical_accuracy: 0.7601 - val_loss: 0.6974 - val_categorical_accuracy: 0.7663 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 0.6527 - categorical_accuracy: 0.7732 - val_loss: 0.6861 - val_categorical_accuracy: 0.7717 - lr: 0.0010 - 969ms/epoch - 6ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 0.6056 - categorical_accuracy: 0.7881 - val_loss: 0.6726 - val_categorical_accuracy: 0.7730 - lr: 5.0000e-04 - 989ms/epoch - 7ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 0.5729 - categorical_accuracy: 0.8003 - val_loss: 0.6444 - val_categorical_accuracy: 0.7830 - lr: 2.5000e-04 - 1s/epoch - 9ms/step
# ----------------------------------------------------------------------
# Estimated runtime for full EA based on this training: 44 to 66 mins.
# ----------------------------------------------------------------------
# Training DNA number: 7
# Epoch 1/12
# 150/150 - 2s - loss: 1.8379 - categorical_accuracy: 0.3426 - val_loss: 4.2755 - val_categorical_accuracy: 0.1077 - lr: 0.0040 - 2s/epoch - 12ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 1.4548 - categorical_accuracy: 0.4730 - val_loss: 2.9105 - val_categorical_accuracy: 0.2367 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 1.2932 - categorical_accuracy: 0.5386 - val_loss: 1.9131 - val_categorical_accuracy: 0.4170 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 1.1652 - categorical_accuracy: 0.5856 - val_loss: 1.1131 - val_categorical_accuracy: 0.6043 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 1.0796 - categorical_accuracy: 0.6209 - val_loss: 0.9730 - val_categorical_accuracy: 0.6553 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 1.0092 - categorical_accuracy: 0.6448 - val_loss: 1.1894 - val_categorical_accuracy: 0.5960 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 0.8986 - categorical_accuracy: 0.6867 - val_loss: 0.8928 - val_categorical_accuracy: 0.6887 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 0.8418 - categorical_accuracy: 0.7049 - val_loss: 1.1799 - val_categorical_accuracy: 0.6247 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 0.7673 - categorical_accuracy: 0.7302 - val_loss: 0.8366 - val_categorical_accuracy: 0.7057 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 0.7553 - categorical_accuracy: 0.7335 - val_loss: 0.8331 - val_categorical_accuracy: 0.7097 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 0.7120 - categorical_accuracy: 0.7491 - val_loss: 0.8132 - val_categorical_accuracy: 0.7187 - lr: 5.0000e-04 - 1s/epoch - 7ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 0.6938 - categorical_accuracy: 0.7544 - val_loss: 0.7749 - val_categorical_accuracy: 0.7300 - lr: 5.0000e-04 - 1s/epoch - 7ms/step
# ----------------------------------------------------------------------
# Estimated runtime for full EA based on this training: 46 to 69 mins.
# ----------------------------------------------------------------------
# Training DNA number: 4
# Epoch 1/12
# 150/150 - 2s - loss: 2.2122 - categorical_accuracy: 0.1659 - val_loss: 2.1098 - val_categorical_accuracy: 0.2000 - lr: 0.0040 - 2s/epoch - 11ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 1.9511 - categorical_accuracy: 0.2294 - val_loss: 2.3343 - val_categorical_accuracy: 0.1727 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 1.7685 - categorical_accuracy: 0.2945 - val_loss: 1.6857 - val_categorical_accuracy: 0.3823 - lr: 0.0020 - 1s/epoch - 8ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 1.6357 - categorical_accuracy: 0.3573 - val_loss: 1.3843 - val_categorical_accuracy: 0.4940 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 1.5097 - categorical_accuracy: 0.4253 - val_loss: 1.2431 - val_categorical_accuracy: 0.5703 - lr: 0.0020 - 1s/epoch - 8ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 1.3925 - categorical_accuracy: 0.4816 - val_loss: 1.1975 - val_categorical_accuracy: 0.5637 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 1.2281 - categorical_accuracy: 0.5477 - val_loss: 1.0810 - val_categorical_accuracy: 0.6340 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 1.1381 - categorical_accuracy: 0.5857 - val_loss: 0.9758 - val_categorical_accuracy: 0.6483 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 1.0678 - categorical_accuracy: 0.6217 - val_loss: 0.9071 - val_categorical_accuracy: 0.6827 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 0.9967 - categorical_accuracy: 0.6458 - val_loss: 0.8591 - val_categorical_accuracy: 0.6913 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 0.9102 - categorical_accuracy: 0.6760 - val_loss: 0.8431 - val_categorical_accuracy: 0.6957 - lr: 5.0000e-04 - 1s/epoch - 8ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 0.8546 - categorical_accuracy: 0.7008 - val_loss: 0.7505 - val_categorical_accuracy: 0.7433 - lr: 5.0000e-04 - 1s/epoch - 9ms/step
# ----------------------------------------------------------------------
# Estimated runtime for full EA based on this training: 47 to 70 mins.
# ----------------------------------------------------------------------
# Training DNA number: 0
# Epoch 1/12
# 150/150 - 2s - loss: 2.0156 - categorical_accuracy: 0.3188 - val_loss: 3.8907 - val_categorical_accuracy: 0.1247 - lr: 0.0040 - 2s/epoch - 12ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 1.4749 - categorical_accuracy: 0.4598 - val_loss: 2.5707 - val_categorical_accuracy: 0.2383 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 1.3088 - categorical_accuracy: 0.5297 - val_loss: 1.4590 - val_categorical_accuracy: 0.5163 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 1.1602 - categorical_accuracy: 0.5855 - val_loss: 1.2415 - val_categorical_accuracy: 0.5807 - lr: 0.0040 - 1s/epoch - 8ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 1.0405 - categorical_accuracy: 0.6367 - val_loss: 1.0821 - val_categorical_accuracy: 0.6283 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 0.9361 - categorical_accuracy: 0.6742 - val_loss: 1.0029 - val_categorical_accuracy: 0.6597 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 0.8537 - categorical_accuracy: 0.7041 - val_loss: 0.9418 - val_categorical_accuracy: 0.6800 - lr: 0.0040 - 1s/epoch - 8ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 0.7828 - categorical_accuracy: 0.7291 - val_loss: 0.7885 - val_categorical_accuracy: 0.7273 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 0.7369 - categorical_accuracy: 0.7496 - val_loss: 0.7464 - val_categorical_accuracy: 0.7497 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 0.6898 - categorical_accuracy: 0.7639 - val_loss: 0.7439 - val_categorical_accuracy: 0.7553 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 0.5633 - categorical_accuracy: 0.8047 - val_loss: 0.6371 - val_categorical_accuracy: 0.7863 - lr: 0.0020 - 1s/epoch - 8ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 0.5164 - categorical_accuracy: 0.8217 - val_loss: 0.6391 - val_categorical_accuracy: 0.7913 - lr: 0.0020 - 1s/epoch - 7ms/step
# ----------------------------------------------------------------------
# Estimated runtime for full EA based on this training: 47 to 70 mins.
# ----------------------------------------------------------------------
# Training DNA number: 3
# Epoch 1/12
# 150/150 - 2s - loss: 1.8735 - categorical_accuracy: 0.3457 - val_loss: 3.5887 - val_categorical_accuracy: 0.1600 - lr: 0.0040 - 2s/epoch - 10ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 1.3904 - categorical_accuracy: 0.4929 - val_loss: 2.1874 - val_categorical_accuracy: 0.2980 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 1.1948 - categorical_accuracy: 0.5736 - val_loss: 1.2577 - val_categorical_accuracy: 0.5583 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 1.0633 - categorical_accuracy: 0.6278 - val_loss: 1.1087 - val_categorical_accuracy: 0.6103 - lr: 0.0040 - 1s/epoch - 8ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 0.9618 - categorical_accuracy: 0.6631 - val_loss: 0.9069 - val_categorical_accuracy: 0.6897 - lr: 0.0040 - 1s/epoch - 8ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 0.8808 - categorical_accuracy: 0.6921 - val_loss: 0.8388 - val_categorical_accuracy: 0.7083 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 0.8106 - categorical_accuracy: 0.7176 - val_loss: 0.8727 - val_categorical_accuracy: 0.7060 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 0.6831 - categorical_accuracy: 0.7647 - val_loss: 0.7045 - val_categorical_accuracy: 0.7570 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 0.6313 - categorical_accuracy: 0.7802 - val_loss: 0.6826 - val_categorical_accuracy: 0.7700 - lr: 0.0020 - 1s/epoch - 8ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 0.5935 - categorical_accuracy: 0.7939 - val_loss: 0.6936 - val_categorical_accuracy: 0.7687 - lr: 0.0020 - 1s/epoch - 8ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 0.5129 - categorical_accuracy: 0.8209 - val_loss: 0.6647 - val_categorical_accuracy: 0.7740 - lr: 0.0010 - 1s/epoch - 9ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 0.4574 - categorical_accuracy: 0.8386 - val_loss: 0.6257 - val_categorical_accuracy: 0.7923 - lr: 5.0000e-04 - 1s/epoch - 8ms/step
# ----------------------------------------------------------------------
# Estimated runtime for full EA based on this training: 48 to 72 mins.
# ----------------------------------------------------------------------
# Training DNA number: 8
# Epoch 1/12
# 150/150 - 2s - loss: 2.1530 - categorical_accuracy: 0.2214 - val_loss: 3.8669 - val_categorical_accuracy: 0.1650 - lr: 0.0040 - 2s/epoch - 11ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 1.7295 - categorical_accuracy: 0.3365 - val_loss: 4.5636 - val_categorical_accuracy: 0.0957 - lr: 0.0040 - 1s/epoch - 8ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 1.5548 - categorical_accuracy: 0.3992 - val_loss: 2.3856 - val_categorical_accuracy: 0.2313 - lr: 0.0020 - 1s/epoch - 8ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 1.4478 - categorical_accuracy: 0.4607 - val_loss: 1.8933 - val_categorical_accuracy: 0.3823 - lr: 0.0020 - 1s/epoch - 8ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 1.3492 - categorical_accuracy: 0.5102 - val_loss: 1.6052 - val_categorical_accuracy: 0.4553 - lr: 0.0020 - 1s/epoch - 8ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 1.2724 - categorical_accuracy: 0.5464 - val_loss: 1.6143 - val_categorical_accuracy: 0.4400 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 1.1800 - categorical_accuracy: 0.5780 - val_loss: 1.3632 - val_categorical_accuracy: 0.5157 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 1.1273 - categorical_accuracy: 0.5983 - val_loss: 1.1613 - val_categorical_accuracy: 0.5740 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 1.1034 - categorical_accuracy: 0.6089 - val_loss: 1.2439 - val_categorical_accuracy: 0.5623 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 1.0563 - categorical_accuracy: 0.6231 - val_loss: 1.1998 - val_categorical_accuracy: 0.5807 - lr: 5.0000e-04 - 1s/epoch - 7ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 1.0192 - categorical_accuracy: 0.6381 - val_loss: 1.1340 - val_categorical_accuracy: 0.5977 - lr: 2.5000e-04 - 1s/epoch - 7ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 1.0130 - categorical_accuracy: 0.6380 - val_loss: 1.1841 - val_categorical_accuracy: 0.5823 - lr: 2.5000e-04 - 948ms/epoch - 6ms/step
# ----------------------------------------------------------------------
# Estimated runtime for full EA based on this training: 46 to 69 mins.
# ----------------------------------------------------------------------
# Training DNA number: 5
# Epoch 1/12
# 150/150 - 1s - loss: 1.9959 - categorical_accuracy: 0.3029 - val_loss: 2.7322 - val_categorical_accuracy: 0.1677 - lr: 0.0040 - 1s/epoch - 10ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 1.5515 - categorical_accuracy: 0.4325 - val_loss: 2.5848 - val_categorical_accuracy: 0.2077 - lr: 0.0040 - 975ms/epoch - 6ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 1.4032 - categorical_accuracy: 0.4935 - val_loss: 1.9855 - val_categorical_accuracy: 0.3583 - lr: 0.0040 - 958ms/epoch - 6ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 1.2684 - categorical_accuracy: 0.5433 - val_loss: 1.2550 - val_categorical_accuracy: 0.5387 - lr: 0.0040 - 980ms/epoch - 7ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 1.1877 - categorical_accuracy: 0.5800 - val_loss: 1.2815 - val_categorical_accuracy: 0.5673 - lr: 0.0040 - 976ms/epoch - 7ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 1.1233 - categorical_accuracy: 0.6048 - val_loss: 1.3406 - val_categorical_accuracy: 0.5557 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 1.0167 - categorical_accuracy: 0.6422 - val_loss: 1.1717 - val_categorical_accuracy: 0.6133 - lr: 0.0020 - 962ms/epoch - 6ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 0.9753 - categorical_accuracy: 0.6597 - val_loss: 1.0142 - val_categorical_accuracy: 0.6543 - lr: 0.0020 - 993ms/epoch - 7ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 0.9385 - categorical_accuracy: 0.6709 - val_loss: 0.8915 - val_categorical_accuracy: 0.6907 - lr: 0.0020 - 972ms/epoch - 6ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 0.9167 - categorical_accuracy: 0.6835 - val_loss: 0.8389 - val_categorical_accuracy: 0.7140 - lr: 0.0020 - 983ms/epoch - 7ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 0.8872 - categorical_accuracy: 0.6909 - val_loss: 0.8258 - val_categorical_accuracy: 0.7103 - lr: 0.0020 - 933ms/epoch - 6ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 0.8248 - categorical_accuracy: 0.7095 - val_loss: 0.8696 - val_categorical_accuracy: 0.7050 - lr: 0.0010 - 938ms/epoch - 6ms/step
# ----------------------------------------------------------------------
# Estimated runtime for full EA based on this training: 41 to 61 mins.
# ----------------------------------------------------------------------
# Training DNA number: 2
# Epoch 1/12
# 150/150 - 2s - loss: 1.7551 - categorical_accuracy: 0.3761 - val_loss: 4.1585 - val_categorical_accuracy: 0.1007 - lr: 0.0040 - 2s/epoch - 10ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 1.3092 - categorical_accuracy: 0.5257 - val_loss: 2.5956 - val_categorical_accuracy: 0.1877 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 1.0856 - categorical_accuracy: 0.6135 - val_loss: 1.4325 - val_categorical_accuracy: 0.5107 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 0.9361 - categorical_accuracy: 0.6719 - val_loss: 1.0015 - val_categorical_accuracy: 0.6500 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 0.8457 - categorical_accuracy: 0.7068 - val_loss: 0.8693 - val_categorical_accuracy: 0.6923 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 0.7771 - categorical_accuracy: 0.7287 - val_loss: 0.8179 - val_categorical_accuracy: 0.7097 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 0.7170 - categorical_accuracy: 0.7499 - val_loss: 0.8287 - val_categorical_accuracy: 0.7160 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 0.5981 - categorical_accuracy: 0.7911 - val_loss: 0.6473 - val_categorical_accuracy: 0.7760 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 0.5464 - categorical_accuracy: 0.8061 - val_loss: 0.6662 - val_categorical_accuracy: 0.7773 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 0.4721 - categorical_accuracy: 0.8355 - val_loss: 0.6155 - val_categorical_accuracy: 0.8017 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 0.4465 - categorical_accuracy: 0.8398 - val_loss: 0.6109 - val_categorical_accuracy: 0.7973 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 0.3990 - categorical_accuracy: 0.8598 - val_loss: 0.5927 - val_categorical_accuracy: 0.8000 - lr: 5.0000e-04 - 1s/epoch - 7ms/step
# ----------------------------------------------------------------------
# Estimated runtime for full EA based on this training: 45 to 68 mins.
# ----------------------------------------------------------------------
# Training DNA number: 6
# Epoch 1/12
# 150/150 - 2s - loss: 2.2155 - categorical_accuracy: 0.3802 - val_loss: 3.4013 - val_categorical_accuracy: 0.1393 - lr: 0.0040 - 2s/epoch - 11ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 1.7142 - categorical_accuracy: 0.5193 - val_loss: 4.3528 - val_categorical_accuracy: 0.1973 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 1.4050 - categorical_accuracy: 0.5902 - val_loss: 1.3616 - val_categorical_accuracy: 0.5543 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 1.1691 - categorical_accuracy: 0.6432 - val_loss: 0.9439 - val_categorical_accuracy: 0.6680 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 0.9657 - categorical_accuracy: 0.6887 - val_loss: 0.8830 - val_categorical_accuracy: 0.6883 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 0.8509 - categorical_accuracy: 0.7134 - val_loss: 1.0324 - val_categorical_accuracy: 0.6680 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 0.6890 - categorical_accuracy: 0.7609 - val_loss: 0.7207 - val_categorical_accuracy: 0.7420 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 0.6416 - categorical_accuracy: 0.7747 - val_loss: 0.6893 - val_categorical_accuracy: 0.7547 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 0.6025 - categorical_accuracy: 0.7868 - val_loss: 0.6910 - val_categorical_accuracy: 0.7597 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 0.5375 - categorical_accuracy: 0.8097 - val_loss: 0.6710 - val_categorical_accuracy: 0.7657 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 0.5077 - categorical_accuracy: 0.8222 - val_loss: 0.6125 - val_categorical_accuracy: 0.7853 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 0.4950 - categorical_accuracy: 0.8247 - val_loss: 0.6281 - val_categorical_accuracy: 0.7837 - lr: 0.0010 - 1s/epoch - 7ms/step
# ----------------------------------------------------------------------
# Estimated runtime for full EA based on this training: 45 to 67 mins.
# ----------------------------------------------------------------------
# Training DNA number: 9
# Epoch 1/12
# 150/150 - 2s - loss: 2.1670 - categorical_accuracy: 0.1871 - val_loss: 3.3616 - val_categorical_accuracy: 0.1033 - lr: 0.0040 - 2s/epoch - 10ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 1.9010 - categorical_accuracy: 0.2589 - val_loss: 2.1100 - val_categorical_accuracy: 0.2337 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 1.7808 - categorical_accuracy: 0.3055 - val_loss: 2.3952 - val_categorical_accuracy: 0.2393 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 1.6260 - categorical_accuracy: 0.3664 - val_loss: 1.5074 - val_categorical_accuracy: 0.4540 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 1.5514 - categorical_accuracy: 0.3955 - val_loss: 1.3408 - val_categorical_accuracy: 0.5183 - lr: 0.0020 - 1s/epoch - 8ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 1.4613 - categorical_accuracy: 0.4418 - val_loss: 1.1917 - val_categorical_accuracy: 0.5870 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 1.3665 - categorical_accuracy: 0.4896 - val_loss: 1.1162 - val_categorical_accuracy: 0.6033 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 1.2806 - categorical_accuracy: 0.5309 - val_loss: 1.0348 - val_categorical_accuracy: 0.6493 - lr: 0.0020 - 1s/epoch - 8ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 1.1984 - categorical_accuracy: 0.5740 - val_loss: 0.9707 - val_categorical_accuracy: 0.6650 - lr: 0.0020 - 1s/epoch - 8ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 1.0993 - categorical_accuracy: 0.6075 - val_loss: 1.0096 - val_categorical_accuracy: 0.6487 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 0.9756 - categorical_accuracy: 0.6561 - val_loss: 0.8193 - val_categorical_accuracy: 0.7053 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 0.9086 - categorical_accuracy: 0.6831 - val_loss: 0.8431 - val_categorical_accuracy: 0.7177 - lr: 0.0010 - 1s/epoch - 7ms/step
# ----------------------------------------------------------------------
# Estimated runtime for full EA based on this training: 45 to 68 mins.
# ----------------------------------------------------------------------
# >>>>>>>> Initial population trained.
# -------------------------------------------------------
# Estimated runtime for full EA is 45 to 68 mins.
# -------------------------------------------------------
# -------------------------------------------------------
# 2025-04-02 10:54:37
# -------------------------------------------------------
# Starting evolution process for 30 rounds with a population size of 10 candidates.
# Evolution round 1 started.
# DNA 10 has hash 9bb2883b5c0a45a70e34b12e70b0daf56589ebe4902bc09d376d552be5985af9
# DNA 11 has hash 89bc457cf38b0b5d5dcf6ab67e0e1c945ae00e3ede70aa6d74e1fef8597c4922
# DNA 12 has hash c34df4f0151f532cb39b10f1888e79434c1253152724f9c28400826cd9434a5e
# DNA 13 has hash 71d852020b6b7140f46bc5477d3af1e0b57eebf88abc749f81a6b036e2551a47
# DNA 14 has hash 8fc4f61b449077cb70662aa1e3646c7cabb28a04cc22f527f3978a0532972d2d
# DNA 15 has hash 91873cb75925ad6b80c36475862cb60684d840cc21344a06deed670e326e19c5
# DNA 16 has hash b8823e4cf015a6ae336613666133ff676fb78b83960332fe1115976d739991a7
# DNA 17 has hash 1c908f818a986dc30c9b798299204244086d1ea67b573e667674817d603421f8
# Training DNA number: 12
# Epoch 1/12
# 150/150 - 2s - loss: 2.0250 - categorical_accuracy: 0.3276 - val_loss: 2.5435 - val_categorical_accuracy: 0.1283 - lr: 0.0040 - 2s/epoch - 10ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 1.5035 - categorical_accuracy: 0.4500 - val_loss: 3.3612 - val_categorical_accuracy: 0.2107 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 1.3209 - categorical_accuracy: 0.5299 - val_loss: 1.5628 - val_categorical_accuracy: 0.4537 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 1.1743 - categorical_accuracy: 0.5874 - val_loss: 1.2331 - val_categorical_accuracy: 0.5560 - lr: 0.0040 - 1s/epoch - 8ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 1.0715 - categorical_accuracy: 0.6252 - val_loss: 1.2949 - val_categorical_accuracy: 0.5510 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 0.9222 - categorical_accuracy: 0.6789 - val_loss: 1.0147 - val_categorical_accuracy: 0.6550 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 0.8613 - categorical_accuracy: 0.6980 - val_loss: 0.8979 - val_categorical_accuracy: 0.6870 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 0.8186 - categorical_accuracy: 0.7154 - val_loss: 0.9059 - val_categorical_accuracy: 0.6897 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 0.7361 - categorical_accuracy: 0.7439 - val_loss: 0.7441 - val_categorical_accuracy: 0.7500 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 0.6973 - categorical_accuracy: 0.7573 - val_loss: 0.7673 - val_categorical_accuracy: 0.7393 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 0.6375 - categorical_accuracy: 0.7759 - val_loss: 0.7199 - val_categorical_accuracy: 0.7563 - lr: 5.0000e-04 - 1s/epoch - 7ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 0.6022 - categorical_accuracy: 0.7876 - val_loss: 0.7132 - val_categorical_accuracy: 0.7537 - lr: 2.5000e-04 - 1s/epoch - 7ms/step
# Training DNA number: 10
# Epoch 1/12
# 150/150 - 2s - loss: 2.3702 - categorical_accuracy: 0.1143 - val_loss: 2.2852 - val_categorical_accuracy: 0.1563 - lr: 0.0040 - 2s/epoch - 11ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 2.2039 - categorical_accuracy: 0.1416 - val_loss: 1.9824 - val_categorical_accuracy: 0.2013 - lr: 0.0040 - 1s/epoch - 8ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 2.1284 - categorical_accuracy: 0.1634 - val_loss: 2.1893 - val_categorical_accuracy: 0.1507 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 2.0206 - categorical_accuracy: 0.2023 - val_loss: 2.0143 - val_categorical_accuracy: 0.2377 - lr: 0.0020 - 1s/epoch - 8ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 1.9179 - categorical_accuracy: 0.2491 - val_loss: 1.7709 - val_categorical_accuracy: 0.3097 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 1.8125 - categorical_accuracy: 0.2927 - val_loss: 1.6467 - val_categorical_accuracy: 0.3763 - lr: 0.0020 - 1s/epoch - 8ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 1.6949 - categorical_accuracy: 0.3437 - val_loss: 1.5399 - val_categorical_accuracy: 0.4357 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 1.5701 - categorical_accuracy: 0.4085 - val_loss: 1.4448 - val_categorical_accuracy: 0.4730 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 1.4641 - categorical_accuracy: 0.4621 - val_loss: 1.7140 - val_categorical_accuracy: 0.4477 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 1.3008 - categorical_accuracy: 0.5295 - val_loss: 1.0704 - val_categorical_accuracy: 0.6227 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 1.1994 - categorical_accuracy: 0.5714 - val_loss: 1.0539 - val_categorical_accuracy: 0.6297 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 1.1031 - categorical_accuracy: 0.6097 - val_loss: 0.9710 - val_categorical_accuracy: 0.6517 - lr: 5.0000e-04 - 1s/epoch - 7ms/step
# Training DNA number: 14
# Epoch 1/12
# 150/150 - 2s - loss: 1.6938 - categorical_accuracy: 0.4069 - val_loss: 3.0350 - val_categorical_accuracy: 0.1787 - lr: 0.0040 - 2s/epoch - 10ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 1.1856 - categorical_accuracy: 0.5725 - val_loss: 2.3378 - val_categorical_accuracy: 0.2790 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 0.9601 - categorical_accuracy: 0.6584 - val_loss: 1.0465 - val_categorical_accuracy: 0.6260 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 0.8237 - categorical_accuracy: 0.7084 - val_loss: 1.2052 - val_categorical_accuracy: 0.5963 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 0.6738 - categorical_accuracy: 0.7611 - val_loss: 0.6989 - val_categorical_accuracy: 0.7500 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 0.6090 - categorical_accuracy: 0.7851 - val_loss: 0.7854 - val_categorical_accuracy: 0.7407 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 0.5177 - categorical_accuracy: 0.8151 - val_loss: 0.6680 - val_categorical_accuracy: 0.7643 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 0.4754 - categorical_accuracy: 0.8302 - val_loss: 0.6306 - val_categorical_accuracy: 0.7837 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 0.4533 - categorical_accuracy: 0.8391 - val_loss: 0.6506 - val_categorical_accuracy: 0.7777 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 0.3886 - categorical_accuracy: 0.8632 - val_loss: 0.5976 - val_categorical_accuracy: 0.8000 - lr: 5.0000e-04 - 1s/epoch - 7ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 0.3665 - categorical_accuracy: 0.8691 - val_loss: 0.6401 - val_categorical_accuracy: 0.7897 - lr: 5.0000e-04 - 1s/epoch - 7ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 0.3325 - categorical_accuracy: 0.8817 - val_loss: 0.5985 - val_categorical_accuracy: 0.8063 - lr: 2.5000e-04 - 1s/epoch - 7ms/step
# Training DNA number: 15
# Epoch 1/12
# 150/150 - 2s - loss: 1.7337 - categorical_accuracy: 0.3795 - val_loss: 3.4520 - val_categorical_accuracy: 0.1630 - lr: 0.0040 - 2s/epoch - 11ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 1.2993 - categorical_accuracy: 0.5334 - val_loss: 2.5365 - val_categorical_accuracy: 0.2877 - lr: 0.0040 - 1s/epoch - 8ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 1.0843 - categorical_accuracy: 0.6166 - val_loss: 1.5593 - val_categorical_accuracy: 0.5140 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 0.9416 - categorical_accuracy: 0.6674 - val_loss: 1.1767 - val_categorical_accuracy: 0.5933 - lr: 0.0040 - 1s/epoch - 8ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 0.8453 - categorical_accuracy: 0.7056 - val_loss: 1.0843 - val_categorical_accuracy: 0.6323 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 0.7748 - categorical_accuracy: 0.7313 - val_loss: 0.8319 - val_categorical_accuracy: 0.7107 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 0.7215 - categorical_accuracy: 0.7523 - val_loss: 0.8127 - val_categorical_accuracy: 0.7210 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 0.6733 - categorical_accuracy: 0.7663 - val_loss: 0.7950 - val_categorical_accuracy: 0.7323 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 0.6454 - categorical_accuracy: 0.7753 - val_loss: 0.8374 - val_categorical_accuracy: 0.7163 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 0.5269 - categorical_accuracy: 0.8157 - val_loss: 0.6364 - val_categorical_accuracy: 0.7863 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 0.4934 - categorical_accuracy: 0.8270 - val_loss: 0.7086 - val_categorical_accuracy: 0.7723 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 0.4320 - categorical_accuracy: 0.8489 - val_loss: 0.6089 - val_categorical_accuracy: 0.8047 - lr: 0.0010 - 1s/epoch - 7ms/step
# Training DNA number: 11
# Epoch 1/12
# 150/150 - 2s - loss: 2.1935 - categorical_accuracy: 0.1826 - val_loss: 2.3827 - val_categorical_accuracy: 0.1780 - lr: 0.0040 - 2s/epoch - 11ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 1.8996 - categorical_accuracy: 0.2561 - val_loss: 3.8637 - val_categorical_accuracy: 0.1367 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 1.6691 - categorical_accuracy: 0.3586 - val_loss: 1.8449 - val_categorical_accuracy: 0.3300 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 1.5147 - categorical_accuracy: 0.4397 - val_loss: 1.3345 - val_categorical_accuracy: 0.5130 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 1.3566 - categorical_accuracy: 0.5174 - val_loss: 1.4164 - val_categorical_accuracy: 0.5003 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 1.1806 - categorical_accuracy: 0.5894 - val_loss: 1.1480 - val_categorical_accuracy: 0.5943 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 1.0848 - categorical_accuracy: 0.6237 - val_loss: 0.9849 - val_categorical_accuracy: 0.6490 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 1.0250 - categorical_accuracy: 0.6462 - val_loss: 0.9872 - val_categorical_accuracy: 0.6573 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 0.9256 - categorical_accuracy: 0.6819 - val_loss: 0.8981 - val_categorical_accuracy: 0.6857 - lr: 5.0000e-04 - 1s/epoch - 8ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 0.8889 - categorical_accuracy: 0.6955 - val_loss: 0.8978 - val_categorical_accuracy: 0.6843 - lr: 5.0000e-04 - 1s/epoch - 7ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 0.8334 - categorical_accuracy: 0.7121 - val_loss: 0.8130 - val_categorical_accuracy: 0.7107 - lr: 2.5000e-04 - 1s/epoch - 7ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 0.8088 - categorical_accuracy: 0.7178 - val_loss: 0.8217 - val_categorical_accuracy: 0.7163 - lr: 2.5000e-04 - 1s/epoch - 7ms/step
# Training DNA number: 17
# Epoch 1/12
# 150/150 - 2s - loss: 2.1763 - categorical_accuracy: 0.2175 - val_loss: 2.8335 - val_categorical_accuracy: 0.1390 - lr: 0.0040 - 2s/epoch - 11ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 1.8273 - categorical_accuracy: 0.2882 - val_loss: 2.6233 - val_categorical_accuracy: 0.1957 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 1.6875 - categorical_accuracy: 0.3445 - val_loss: 2.4754 - val_categorical_accuracy: 0.2040 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 1.5316 - categorical_accuracy: 0.4019 - val_loss: 1.4037 - val_categorical_accuracy: 0.4677 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 1.4536 - categorical_accuracy: 0.4329 - val_loss: 1.3284 - val_categorical_accuracy: 0.5300 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 1.3899 - categorical_accuracy: 0.4639 - val_loss: 1.2538 - val_categorical_accuracy: 0.5420 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 1.3056 - categorical_accuracy: 0.5067 - val_loss: 1.1538 - val_categorical_accuracy: 0.5880 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 1.2315 - categorical_accuracy: 0.5486 - val_loss: 1.1057 - val_categorical_accuracy: 0.6150 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 1.1671 - categorical_accuracy: 0.5764 - val_loss: 1.0410 - val_categorical_accuracy: 0.6557 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 1.0673 - categorical_accuracy: 0.6231 - val_loss: 1.0043 - val_categorical_accuracy: 0.6483 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 0.9218 - categorical_accuracy: 0.6781 - val_loss: 0.8253 - val_categorical_accuracy: 0.7227 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 0.8478 - categorical_accuracy: 0.7074 - val_loss: 0.8164 - val_categorical_accuracy: 0.7360 - lr: 0.0010 - 1s/epoch - 7ms/step
# Training DNA number: 13
# Epoch 1/12
# 150/150 - 2s - loss: 2.1393 - categorical_accuracy: 0.2984 - val_loss: 2.6121 - val_categorical_accuracy: 0.1753 - lr: 0.0040 - 2s/epoch - 10ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 1.5603 - categorical_accuracy: 0.4270 - val_loss: 2.1931 - val_categorical_accuracy: 0.2687 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 1.3473 - categorical_accuracy: 0.5143 - val_loss: 1.2752 - val_categorical_accuracy: 0.5337 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 1.1940 - categorical_accuracy: 0.5764 - val_loss: 1.2689 - val_categorical_accuracy: 0.5627 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 1.0754 - categorical_accuracy: 0.6236 - val_loss: 1.1629 - val_categorical_accuracy: 0.6000 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 1.0022 - categorical_accuracy: 0.6472 - val_loss: 0.9510 - val_categorical_accuracy: 0.6663 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 0.9226 - categorical_accuracy: 0.6785 - val_loss: 1.0742 - val_categorical_accuracy: 0.6473 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 0.8060 - categorical_accuracy: 0.7170 - val_loss: 0.7352 - val_categorical_accuracy: 0.7477 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 0.7615 - categorical_accuracy: 0.7336 - val_loss: 0.7067 - val_categorical_accuracy: 0.7533 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 0.6834 - categorical_accuracy: 0.7623 - val_loss: 0.6748 - val_categorical_accuracy: 0.7717 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 0.6566 - categorical_accuracy: 0.7700 - val_loss: 0.6889 - val_categorical_accuracy: 0.7627 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 0.6151 - categorical_accuracy: 0.7854 - val_loss: 0.6479 - val_categorical_accuracy: 0.7860 - lr: 5.0000e-04 - 1s/epoch - 7ms/step
# Training DNA number: 16
# Epoch 1/12
# 150/150 - 1s - loss: 2.3162 - categorical_accuracy: 0.1512 - val_loss: 2.1405 - val_categorical_accuracy: 0.2073 - lr: 0.0040 - 1s/epoch - 9ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 2.0156 - categorical_accuracy: 0.2185 - val_loss: 2.0611 - val_categorical_accuracy: 0.2217 - lr: 0.0040 - 978ms/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 1.9020 - categorical_accuracy: 0.2599 - val_loss: 1.9591 - val_categorical_accuracy: 0.3127 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 1.8018 - categorical_accuracy: 0.3063 - val_loss: 1.5881 - val_categorical_accuracy: 0.3750 - lr: 0.0040 - 992ms/epoch - 7ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 1.6977 - categorical_accuracy: 0.3508 - val_loss: 1.5313 - val_categorical_accuracy: 0.4153 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 1.6214 - categorical_accuracy: 0.3895 - val_loss: 1.4478 - val_categorical_accuracy: 0.4557 - lr: 0.0040 - 972ms/epoch - 6ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 1.5345 - categorical_accuracy: 0.4157 - val_loss: 1.6586 - val_categorical_accuracy: 0.4307 - lr: 0.0040 - 949ms/epoch - 6ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 1.4096 - categorical_accuracy: 0.4740 - val_loss: 1.3014 - val_categorical_accuracy: 0.5590 - lr: 0.0020 - 984ms/epoch - 7ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 1.3105 - categorical_accuracy: 0.5160 - val_loss: 1.0741 - val_categorical_accuracy: 0.6223 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 1.2472 - categorical_accuracy: 0.5442 - val_loss: 1.1416 - val_categorical_accuracy: 0.6090 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 1.1453 - categorical_accuracy: 0.5856 - val_loss: 0.9467 - val_categorical_accuracy: 0.6780 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 1.0848 - categorical_accuracy: 0.6152 - val_loss: 1.0317 - val_categorical_accuracy: 0.6473 - lr: 0.0010 - 945ms/epoch - 6ms/step
# ~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######
# Acc Limit = 0.7 in Evolution round 1
# ~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######
# Removed DNA 10 because of bad acc of 0.6516666412353516
# Removed DNA 16 because of bad acc of 0.6779999732971191
# Removed DNA 8 because of bad acc of 0.5976666808128357
# Poplist length: 15
# Evolution round 1 finished. Population size: 10
# -------------------------------------------------------
# 2025-04-02 10:56:25
# -------------------------------------------------------
# Evolution round 2 started.
# DNA 18 has hash 7099de05eeff22c3b433621e6a703908ee0eb0efe3894de4a5a057446b7ccc88
# DNA 19 has hash 7291b461da949aa2ca6da4546754a898f3ea0dd0f51d1524f56908652003f335
# DNA 20 has hash b1e9eec41b741dbbf068cbfc8341cb78a0fd1fc424355045a7a4fe3ee3a3dcd7
# DNA 21 has hash 692c29850abb93fd5d215001e3abd2856abc68406655c320d3b56a9234d29ee3
# DNA 22 has hash 9152ec2a2c7d87b0f286898800322677b90fec2cb6c63bb01f339399f00c3706
# DNA 23 has hash a44fe146a534c998b72a0b34b86d41b4c8b3d59542df91521d466b3dcefaebf0
# DNA 24 has hash 1d40f6402a0183d1b6a3a64c307fa13993e4f0fdfa8701ab9a0f114c0cc38a8b
# DNA 25 has hash 3bfc048dd774637791625d27bcf62d72f37d4bfa25e8087fc0fdc497ec961844
# Training DNA number: 20
# Epoch 1/12
# 150/150 - 2s - loss: 1.7635 - categorical_accuracy: 0.3598 - val_loss: 2.8044 - val_categorical_accuracy: 0.1837 - lr: 0.0040 - 2s/epoch - 10ms/step
# Epoch 2/12
# ...
# Training DNA number: 237
# Epoch 1/12
# 150/150 - 2s - loss: 2.4343 - categorical_accuracy: 0.0999 - val_loss: 2.3024 - val_categorical_accuracy: 0.1057 - lr: 0.0040 - 2s/epoch - 12ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 2.3028 - categorical_accuracy: 0.0986 - val_loss: 2.3028 - val_categorical_accuracy: 0.0940 - lr: 0.0040 - 1s/epoch - 8ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 2.3028 - categorical_accuracy: 0.0992 - val_loss: 2.3027 - val_categorical_accuracy: 0.0997 - lr: 0.0020 - 1s/epoch - 8ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 2.3026 - categorical_accuracy: 0.0982 - val_loss: 2.3031 - val_categorical_accuracy: 0.0933 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 2.3025 - categorical_accuracy: 0.1019 - val_loss: 2.3032 - val_categorical_accuracy: 0.0940 - lr: 5.0000e-04 - 1s/epoch - 8ms/step
# Training DNA number: 241
# Epoch 1/12
# 150/150 - 2s - loss: 2.4828 - categorical_accuracy: 0.0996 - val_loss: 2.3028 - val_categorical_accuracy: 0.1007 - lr: 0.0040 - 2s/epoch - 10ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 2.3028 - categorical_accuracy: 0.0972 - val_loss: 2.3027 - val_categorical_accuracy: 0.1070 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 2.3026 - categorical_accuracy: 0.0973 - val_loss: 2.3029 - val_categorical_accuracy: 0.0943 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 2.3026 - categorical_accuracy: 0.1020 - val_loss: 2.3028 - val_categorical_accuracy: 0.0943 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 2.3025 - categorical_accuracy: 0.1008 - val_loss: 2.3028 - val_categorical_accuracy: 0.0940 - lr: 5.0000e-04 - 1s/epoch - 7ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 2.3025 - categorical_accuracy: 0.1019 - val_loss: 2.3028 - val_categorical_accuracy: 0.0940 - lr: 2.5000e-04 - 1s/epoch - 7ms/step
# Training DNA number: 238
# Epoch 1/12
# 150/150 - 2s - loss: 2.4851 - categorical_accuracy: 0.1000 - val_loss: 2.3027 - val_categorical_accuracy: 0.1007 - lr: 0.0040 - 2s/epoch - 11ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 2.3029 - categorical_accuracy: 0.0987 - val_loss: 2.3028 - val_categorical_accuracy: 0.0940 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 2.3027 - categorical_accuracy: 0.1013 - val_loss: 2.3028 - val_categorical_accuracy: 0.0940 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 2.3026 - categorical_accuracy: 0.1019 - val_loss: 2.3027 - val_categorical_accuracy: 0.0940 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 2.3025 - categorical_accuracy: 0.1019 - val_loss: 2.3028 - val_categorical_accuracy: 0.0940 - lr: 5.0000e-04 - 1s/epoch - 7ms/step
# Training DNA number: 236
# Epoch 1/12
# 150/150 - 2s - loss: 2.4344 - categorical_accuracy: 0.0999 - val_loss: 2.3052 - val_categorical_accuracy: 0.0977 - lr: 0.0040 - 2s/epoch - 11ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 2.3032 - categorical_accuracy: 0.0986 - val_loss: 2.3052 - val_categorical_accuracy: 0.1047 - lr: 0.0040 - 1s/epoch - 8ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 2.3030 - categorical_accuracy: 0.0979 - val_loss: 2.3026 - val_categorical_accuracy: 0.0933 - lr: 0.0020 - 1s/epoch - 8ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 2.3027 - categorical_accuracy: 0.1019 - val_loss: 2.3027 - val_categorical_accuracy: 0.0940 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 2.3025 - categorical_accuracy: 0.1020 - val_loss: 2.3028 - val_categorical_accuracy: 0.0950 - lr: 5.0000e-04 - 1s/epoch - 8ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 2.3025 - categorical_accuracy: 0.1022 - val_loss: 2.3022 - val_categorical_accuracy: 0.0963 - lr: 2.5000e-04 - 1s/epoch - 7ms/step
# ~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######
# Acc Limit = 0.98 in Evolution round 29
# ~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######
# Removed DNA 234 because of bad acc of 0.10700000077486038
# Removed DNA 239 because of bad acc of 0.10166666656732559
# Removed DNA 235 because of bad acc of 0.09933333098888397
# Removed DNA 240 because of bad acc of 0.10066666454076767
# Removed DNA 237 because of bad acc of 0.10566666722297668
# Removed DNA 241 because of bad acc of 0.10700000077486038
# Removed DNA 238 because of bad acc of 0.10066666454076767
# Removed DNA 236 because of bad acc of 0.10466666519641876
# Removed DNA 209 because of bad acc of 0.10066666454076767
# Removed DNA 225 because of bad acc of 0.10066666454076767
# Removed DNA 232 because of bad acc of 0.10166666656732559
# Removed DNA 199 because of bad acc of 0.09399999678134918
# Removed DNA 176 because of bad acc of 0.10066666454076767
# Removed DNA 200 because of bad acc of 0.09433333575725555
# Removed DNA 190 because of bad acc of 0.10066666454076767
# Removed DNA 197 because of bad acc of 0.10066666454076767
# Removed DNA 179 because of bad acc of 0.10066666454076767
# Removed DNA 228 because of bad acc of 0.09933333098888397
# Good set is missing 10 DNAs
# Poplist length: 0
# Evolution round 29 finished. Population size: 10
# -------------------------------------------------------
# 2025-04-02 11:38:32
# -------------------------------------------------------
# Evolution round 30 started.
# DNA 242 has hash 10129850f56964196938a3484689d4e41368ead30c522cd5b73b487985bbd98f
# DNA 243 has hash 0a7da09d7450d8cf394d05a3f6790a813e9a1c99623e91ce326942970ea719e2
# DNA 244 has hash 8bba26d508c96df2ec64c762e02dfb8ef1450e643647acd50c3269cfc6ec494a
# DNA 245 has hash 0f81ce67130a36cad465f68224d0398c5b44dd6d4481c643f6d5896eab61735d
# DNA 246 has hash a390ffaf43d6521c7f285f9b380cacf67adfb2602646562e4ab0710036cc6430
# DNA 247 has hash 54df6047377ac7b89732a229cf9ab8b1c0a25e5c4610eb5e2af07ace5b59e9ea
# DNA 248 has hash 62080d28f83282ad55c0bea9de8f599e779e663e423edbda30a153798b6da003
# DNA 249 has hash 8ba1003b0af01280ecbd0e010af6b3ad6dfbe446bb9402f42496434df7119174
# Training DNA number: 243
# Epoch 1/12
# 150/150 - 2s - loss: 2.4689 - categorical_accuracy: 0.0976 - val_loss: 2.3192 - val_categorical_accuracy: 0.0740 - lr: 0.0040 - 2s/epoch - 11ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 2.3028 - categorical_accuracy: 0.0986 - val_loss: 2.3157 - val_categorical_accuracy: 0.1020 - lr: 0.0040 - 1s/epoch - 8ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 2.3028 - categorical_accuracy: 0.0963 - val_loss: 2.3112 - val_categorical_accuracy: 0.1073 - lr: 0.0040 - 1s/epoch - 8ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 2.3027 - categorical_accuracy: 0.0999 - val_loss: 2.3047 - val_categorical_accuracy: 0.1093 - lr: 0.0020 - 1s/epoch - 8ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 2.3026 - categorical_accuracy: 0.0992 - val_loss: 2.3039 - val_categorical_accuracy: 0.0963 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 2.3026 - categorical_accuracy: 0.1019 - val_loss: 2.3037 - val_categorical_accuracy: 0.0963 - lr: 5.0000e-04 - 1s/epoch - 8ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 2.3025 - categorical_accuracy: 0.1019 - val_loss: 2.3036 - val_categorical_accuracy: 0.0950 - lr: 2.5000e-04 - 1s/epoch - 7ms/step
# Training DNA number: 249
# Epoch 1/12
# 150/150 - 2s - loss: 2.3364 - categorical_accuracy: 0.0996 - val_loss: 28.0187 - val_categorical_accuracy: 0.1070 - lr: 0.0040 - 2s/epoch - 11ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 2.3031 - categorical_accuracy: 0.1011 - val_loss: 3.9772 - val_categorical_accuracy: 0.0833 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 2.3029 - categorical_accuracy: 0.0966 - val_loss: 8.3416 - val_categorical_accuracy: 0.0937 - lr: 0.0020 - 1s/epoch - 8ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 2.3026 - categorical_accuracy: 0.1000 - val_loss: 8.0901 - val_categorical_accuracy: 0.0847 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 2.3026 - categorical_accuracy: 0.0998 - val_loss: 7.7870 - val_categorical_accuracy: 0.0733 - lr: 5.0000e-04 - 1s/epoch - 7ms/step
# Training DNA number: 242
# Epoch 1/12
# 150/150 - 1s - loss: 2.4833 - categorical_accuracy: 0.0971 - val_loss: 2.3025 - val_categorical_accuracy: 0.1010 - lr: 0.0040 - 1s/epoch - 10ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 2.3028 - categorical_accuracy: 0.0993 - val_loss: 2.3027 - val_categorical_accuracy: 0.0943 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 2.3028 - categorical_accuracy: 0.0996 - val_loss: 2.3027 - val_categorical_accuracy: 0.1010 - lr: 0.0020 - 949ms/epoch - 6ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 2.3026 - categorical_accuracy: 0.0995 - val_loss: 2.3027 - val_categorical_accuracy: 0.0940 - lr: 0.0010 - 948ms/epoch - 6ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 2.3026 - categorical_accuracy: 0.1011 - val_loss: 2.3028 - val_categorical_accuracy: 0.0940 - lr: 5.0000e-04 - 948ms/epoch - 6ms/step
# Training DNA number: 247
# Epoch 1/12
# 150/150 - 2s - loss: 2.5338 - categorical_accuracy: 0.0977 - val_loss: 3.6161 - val_categorical_accuracy: 0.0900 - lr: 0.0040 - 2s/epoch - 10ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 2.3032 - categorical_accuracy: 0.0981 - val_loss: 5.0199 - val_categorical_accuracy: 0.0927 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 2.3027 - categorical_accuracy: 0.1020 - val_loss: 7.3451 - val_categorical_accuracy: 0.1090 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 2.3028 - categorical_accuracy: 0.0962 - val_loss: 8.5635 - val_categorical_accuracy: 0.1263 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 2.3027 - categorical_accuracy: 0.1013 - val_loss: 8.6451 - val_categorical_accuracy: 0.1220 - lr: 0.0020 - 991ms/epoch - 7ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 2.3026 - categorical_accuracy: 0.1007 - val_loss: 9.0843 - val_categorical_accuracy: 0.1257 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 2.3026 - categorical_accuracy: 0.1005 - val_loss: 9.0881 - val_categorical_accuracy: 0.1250 - lr: 5.0000e-04 - 1s/epoch - 7ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 2.3025 - categorical_accuracy: 0.1020 - val_loss: 9.1335 - val_categorical_accuracy: 0.1263 - lr: 2.5000e-04 - 991ms/epoch - 7ms/step
# Training DNA number: 244
# Epoch 1/12
# 150/150 - 2s - loss: 2.4884 - categorical_accuracy: 0.0987 - val_loss: 2.3028 - val_categorical_accuracy: 0.0993 - lr: 0.0040 - 2s/epoch - 11ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 2.2875 - categorical_accuracy: 0.1160 - val_loss: 2.4692 - val_categorical_accuracy: 0.0993 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 2.2367 - categorical_accuracy: 0.1427 - val_loss: 2.5504 - val_categorical_accuracy: 0.1060 - lr: 0.0020 - 1s/epoch - 8ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 2.1798 - categorical_accuracy: 0.1607 - val_loss: 2.5365 - val_categorical_accuracy: 0.1463 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 2.1427 - categorical_accuracy: 0.1698 - val_loss: 2.5047 - val_categorical_accuracy: 0.1517 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 2.1015 - categorical_accuracy: 0.1815 - val_loss: 2.8489 - val_categorical_accuracy: 0.1403 - lr: 5.0000e-04 - 1s/epoch - 7ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 2.0830 - categorical_accuracy: 0.1855 - val_loss: 2.4136 - val_categorical_accuracy: 0.1703 - lr: 2.5000e-04 - 1s/epoch - 7ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 2.0691 - categorical_accuracy: 0.1879 - val_loss: 2.4199 - val_categorical_accuracy: 0.1657 - lr: 2.5000e-04 - 1s/epoch - 7ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 2.0624 - categorical_accuracy: 0.1910 - val_loss: 2.5283 - val_categorical_accuracy: 0.1787 - lr: 1.2500e-04 - 1s/epoch - 7ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 2.0574 - categorical_accuracy: 0.1922 - val_loss: 2.3912 - val_categorical_accuracy: 0.1847 - lr: 6.2500e-05 - 1s/epoch - 7ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 2.0518 - categorical_accuracy: 0.1913 - val_loss: 2.5014 - val_categorical_accuracy: 0.1620 - lr: 6.2500e-05 - 1s/epoch - 7ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 2.0518 - categorical_accuracy: 0.1910 - val_loss: 2.4310 - val_categorical_accuracy: 0.1763 - lr: 3.1250e-05 - 1s/epoch - 7ms/step
# Training DNA number: 245
# Epoch 1/12
# 150/150 - 2s - loss: 2.4868 - categorical_accuracy: 0.0957 - val_loss: 2.3026 - val_categorical_accuracy: 0.1007 - lr: 0.0040 - 2s/epoch - 10ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 2.3031 - categorical_accuracy: 0.0985 - val_loss: 2.3028 - val_categorical_accuracy: 0.0940 - lr: 0.0040 - 997ms/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 2.3030 - categorical_accuracy: 0.1004 - val_loss: 2.3027 - val_categorical_accuracy: 0.0940 - lr: 0.0020 - 988ms/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 2.3023 - categorical_accuracy: 0.1016 - val_loss: 2.3028 - val_categorical_accuracy: 0.0930 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 2.3006 - categorical_accuracy: 0.1052 - val_loss: 2.3093 - val_categorical_accuracy: 0.0700 - lr: 5.0000e-04 - 1s/epoch - 7ms/step
# Training DNA number: 248
# Epoch 1/12
# 150/150 - 2s - loss: 2.3650 - categorical_accuracy: 0.0993 - val_loss: 2.3028 - val_categorical_accuracy: 0.1067 - lr: 0.0040 - 2s/epoch - 11ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 2.3029 - categorical_accuracy: 0.0994 - val_loss: 2.3173 - val_categorical_accuracy: 0.1007 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 2.3027 - categorical_accuracy: 0.1001 - val_loss: 2.3207 - val_categorical_accuracy: 0.0903 - lr: 0.0020 - 1s/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 2.3026 - categorical_accuracy: 0.0992 - val_loss: 2.3219 - val_categorical_accuracy: 0.0923 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 2.3026 - categorical_accuracy: 0.0998 - val_loss: 2.3353 - val_categorical_accuracy: 0.0933 - lr: 5.0000e-04 - 1s/epoch - 7ms/step
# Training DNA number: 246
# Epoch 1/12
# 150/150 - 1s - loss: 2.4523 - categorical_accuracy: 0.0989 - val_loss: 5.3713 - val_categorical_accuracy: 0.1097 - lr: 0.0040 - 1s/epoch - 10ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 2.3030 - categorical_accuracy: 0.0973 - val_loss: 7.6565 - val_categorical_accuracy: 0.1107 - lr: 0.0040 - 1s/epoch - 7ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 2.3027 - categorical_accuracy: 0.1019 - val_loss: 9.3157 - val_categorical_accuracy: 0.1080 - lr: 0.0020 - 985ms/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 2.3026 - categorical_accuracy: 0.0984 - val_loss: 9.1428 - val_categorical_accuracy: 0.1073 - lr: 0.0010 - 972ms/epoch - 6ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 2.3025 - categorical_accuracy: 0.1019 - val_loss: 8.7921 - val_categorical_accuracy: 0.1073 - lr: 5.0000e-04 - 1000ms/epoch - 7ms/step
# ~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######
# Acc Limit = 0.99 in Evolution round 30
# ~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######~~~~~~######
# Removed DNA 243 because of bad acc of 0.1093333289027214
# Removed DNA 249 because of bad acc of 0.10700000077486038
# Removed DNA 242 because of bad acc of 0.10099999606609344
# Removed DNA 247 because of bad acc of 0.1263333261013031
# Removed DNA 244 because of bad acc of 0.18466666340827942
# Removed DNA 245 because of bad acc of 0.10066666454076767
# Removed DNA 248 because of bad acc of 0.1066666692495346
# Removed DNA 246 because of bad acc of 0.1106666624546051
# Removed DNA 209 because of bad acc of 0.10066666454076767
# Removed DNA 225 because of bad acc of 0.10066666454076767
# Removed DNA 199 because of bad acc of 0.09399999678134918
# Removed DNA 235 because of bad acc of 0.09933333098888397
# Removed DNA 176 because of bad acc of 0.10066666454076767
# Removed DNA 240 because of bad acc of 0.10066666454076767
# Removed DNA 200 because of bad acc of 0.09433333575725555
# Removed DNA 238 because of bad acc of 0.10066666454076767
# Removed DNA 190 because of bad acc of 0.10066666454076767
# Removed DNA 228 because of bad acc of 0.09933333098888397
# Good set is missing 10 DNAs
# Poplist length: 0
# Evolution round 30 finished. Population size: 10
# -------------------------------------------------------
# 2025-04-02 11:39:33
# -------------------------------------------------------
# >>>>>>>> End of EAS

# %%
# verify DNA 0 model on test dataset
# if not happy --> adjust training parameters

# %run -m evaluate_model best_model_dna_0
# Out:
# Evaluating model: best_model_dna_0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  activation_1 (Activation)   (None, 32, 32, 32)        0
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  activation_2 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  activation_3 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_3 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  activation_4 (Activation)   (None, 8, 8, 128)         0
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  activation_5 (Activation)   (None, 8, 8, 128)         0
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  activation_6 (Activation)   (None, 128)               0
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
#  softmax (Softmax)           (None, 10)                0
#
# =================================================================
# Total params: 552,362
# Trainable params: 551,466
# Non-trainable params: 896
# _________________________________________________________________
# x_train shape: (30000, 32, 32, 3, 1)
# 30000 train samples
# Balance:  {0: 3035, 1: 3019, 2: 3026, 3: 3007, 4: 3019, 5: 2950, 6: 2953, 7: 3007, 8: 2969, 9: 3015}
# 3000 val samples
# Balance:  {0: 284, 1: 313, 2: 306, 3: 300, 4: 320, 5: 291, 6: 301, 7: 290, 8: 308, 9: 287}
# 10000 test samples
# Balance:  {0: 1000, 1: 1000, 2: 1000, 3: 1000, 4: 1000, 5: 1000, 6: 1000, 7: 1000, 8: 1000, 9: 1000}
# 50/50 [==============================] - 1s 7ms/step - loss: 0.6281 - categorical_accuracy: 0.7880
# Test Loss: 0.6281, Test Accuracy: 0.7880

# %%
# %run -m plot_rank_func 38000000 70 15000000 80

# %%
# search space constraints: 
# max_mac 
# max_param

# %%
# 2D Ranking Function: 

# sigma_acc 
# mu_mac 
# sigma_mac 

# example: DNA 0 has accuracy 94.9% and mac 2440000, we want 99% accuracy and 300000 mac
# %run -m plot_rank_func 2440000 94.9 300000 99

# %%
# %run -m run_analysis 5 0.78
# Out:
# ------------------------------------------------------------------------------
# Best networks by accuracy only:
# 1: DNA 54: Acc=0.8186666369438171 with 38638592 MACs and 293930 parameters, Generation 6 with 4 mutations
# 2: DNA 72: Acc=0.8166666626930237 with 38638592 MACs and 293930 parameters, Generation 8 with 4 mutations
# 3: DNA 75: Acc=0.8140000104904175 with 38821392 MACs and 477090 parameters, Generation 9 with 3 mutations
# 4: DNA 102: Acc=0.8113332986831665 with 37448396 MACs and 295910 parameters, Generation 12 with 3 mutations
# 5: DNA 87: Acc=0.8073333501815796 with 29803776 MACs and 306602 parameters, Generation 10 with 4 mutations
# ------------------------------------------------------------------------------
# Best networks by number of MACs only:
# DNA 58: Acc=0.6306666731834412 with 2415872 MACs and 290090 parameters, Generation 7 with 5 mutations
# DNA 165: Acc=0.382999986410141 with 3261696 MACs and 306218 parameters, Generation 20 with 7 mutations
# DNA 81: Acc=0.5920000076293945 with 4171200 MACs and 333862 parameters, Generation 9 with 3 mutations
# DNA 130: Acc=0.6396666765213013 with 5715784 MACs and 244262 parameters, Generation 16 with 6 mutations
# DNA 217: Acc=0.137333333492279 with 7316736 MACs and 296970 parameters, Generation 26 with 10 mutations
# ------------------------------------------------------------------------------
# Best networks by number of MACs with accuracy of min. 0.78:
# DNA 59: Acc=0.7836666703224182 with 28017920 MACs and 290090 parameters, Generation 7 with 5 mutations
# DNA 20: Acc=0.7863333225250244 with 28083456 MACs and 355754 parameters, Generation 2 with 2 mutations
# DNA 65: Acc=0.7876666784286499 with 29201408 MACs and 284554 parameters, Generation 7 with 4 mutations
# DNA 1: Acc=0.7829999923706055 with 29459712 MACs and 404266 parameters, Generation 0 with 1 mutations
# DNA 90: Acc=0.7876666784286499 with 29505352 MACs and 561158 parameters, Generation 11 with 3 mutations
# ------------------------------------------------------------------------------

# %%
# plot scatter
# %run -m plot_acc_macs 4 0.2
# Out:
# Total # of DNAs created: 250

# %%
# %run -m visualize_cnn_arch 59
# Out:
# Visualizing DNA ID: 59
# Found DNA ID 59

# %%
# %run -m evaluate_model best_model_dna_59
# Out:
# Evaluating model: best_model_dna_59
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        896
#
#  activation_6 (Activation)   (None, 32, 32, 32)        0
#
#  batch_normalization_6 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        9248
#
#  activation_7 (Activation)   (None, 32, 32, 32)        0
#
#  batch_normalization_7 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 64)        18496
#
#  activation_8 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_8 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 64)        36928
#
#  activation_9 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_9 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_6 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_10 (Conv2D)          (None, 4, 4, 128)         73856
#
#  activation_10 (Activation)  (None, 4, 4, 128)         0
#
#  batch_normalization_10 (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 4, 4, 128)         147584
#
#  activation_11 (Activation)  (None, 4, 4, 128)         0
#
#  batch_normalization_11 (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout_7 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
#  softmax_1 (Softmax)         (None, 10)                0
#
# =================================================================
# Total params: 290,090
# Trainable params: 289,194
# Non-trainable params: 896
# _________________________________________________________________
# x_train shape: (30000, 32, 32, 3, 1)
# 30000 train samples
# Balance:  {0: 3032, 1: 2972, 2: 2984, 3: 3048, 4: 2988, 5: 2961, 6: 3031, 7: 3000, 8: 3032, 9: 2952}
# 3000 val samples
# Balance:  {0: 307, 1: 319, 2: 293, 3: 302, 4: 313, 5: 315, 6: 283, 7: 307, 8: 274, 9: 287}
# 10000 test samples
# Balance:  {0: 1000, 1: 1000, 2: 1000, 3: 1000, 4: 1000, 5: 1000, 6: 1000, 7: 1000, 8: 1000, 9: 1000}
# 50/50 [==============================] - 1s 3ms/step - loss: 0.6212 - categorical_accuracy: 0.7880
# Test Loss: 0.6212, Test Accuracy: 0.7880

# %%
# %run -m visualize_cnn_arch 59
# Out:
# Visualizing DNA ID: 59
# Found DNA ID 59

# %%
# %run -m evaluate_model best_model_dna_59
# Out:
# Evaluating model: best_model_dna_59
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        896
#
#  activation_6 (Activation)   (None, 32, 32, 32)        0
#
#  batch_normalization_6 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        9248
#
#  activation_7 (Activation)   (None, 32, 32, 32)        0
#
#  batch_normalization_7 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 64)        18496
#
#  activation_8 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_8 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 64)        36928
#
#  activation_9 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_9 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_6 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_10 (Conv2D)          (None, 4, 4, 128)         73856
#
#  activation_10 (Activation)  (None, 4, 4, 128)         0
#
#  batch_normalization_10 (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 4, 4, 128)         147584
#
#  activation_11 (Activation)  (None, 4, 4, 128)         0
#
#  batch_normalization_11 (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout_7 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
#  softmax_1 (Softmax)         (None, 10)                0
#
# =================================================================
# Total params: 290,090
# Trainable params: 289,194
# Non-trainable params: 896
# _________________________________________________________________
# x_train shape: (30000, 32, 32, 3, 1)
# 30000 train samples
# Balance:  {0: 2931, 1: 3003, 2: 2963, 3: 2973, 4: 3048, 5: 3010, 6: 2962, 7: 3050, 8: 3030, 9: 3030}
# 3000 val samples
# Balance:  {0: 302, 1: 312, 2: 322, 3: 307, 4: 289, 5: 297, 6: 324, 7: 268, 8: 278, 9: 301}
# 10000 test samples
# Balance:  {0: 1000, 1: 1000, 2: 1000, 3: 1000, 4: 1000, 5: 1000, 6: 1000, 7: 1000, 8: 1000, 9: 1000}
# 50/50 [==============================] - 0s 7ms/step - loss: 0.6212 - categorical_accuracy: 0.7880
# Test Loss: 0.6212, Test Accuracy: 0.7880
# Start retraining with 12 epochs....
# Epoch 1/12
# 150/150 - 2s - loss: 0.6025 - categorical_accuracy: 0.7919 - val_loss: 0.4908 - val_categorical_accuracy: 0.8320 - 2s/epoch - 11ms/step
# Epoch 2/12
# 150/150 - 1s - loss: 0.5721 - categorical_accuracy: 0.8025 - val_loss: 0.5079 - val_categorical_accuracy: 0.8220 - 967ms/epoch - 6ms/step
# Epoch 3/12
# 150/150 - 1s - loss: 0.5532 - categorical_accuracy: 0.8077 - val_loss: 0.5273 - val_categorical_accuracy: 0.8160 - 981ms/epoch - 7ms/step
# Epoch 4/12
# 150/150 - 1s - loss: 0.5350 - categorical_accuracy: 0.8131 - val_loss: 0.5149 - val_categorical_accuracy: 0.8210 - 967ms/epoch - 6ms/step
# Epoch 5/12
# 150/150 - 1s - loss: 0.5088 - categorical_accuracy: 0.8229 - val_loss: 0.4940 - val_categorical_accuracy: 0.8333 - 983ms/epoch - 7ms/step
# Epoch 6/12
# 150/150 - 1s - loss: 0.5030 - categorical_accuracy: 0.8247 - val_loss: 0.4955 - val_categorical_accuracy: 0.8330 - 969ms/epoch - 6ms/step
# Epoch 7/12
# 150/150 - 1s - loss: 0.4795 - categorical_accuracy: 0.8341 - val_loss: 0.5079 - val_categorical_accuracy: 0.8253 - 970ms/epoch - 6ms/step
# Epoch 8/12
# 150/150 - 1s - loss: 0.4666 - categorical_accuracy: 0.8396 - val_loss: 0.5002 - val_categorical_accuracy: 0.8283 - 972ms/epoch - 6ms/step
# Epoch 9/12
# 150/150 - 1s - loss: 0.4553 - categorical_accuracy: 0.8426 - val_loss: 0.5671 - val_categorical_accuracy: 0.8093 - 975ms/epoch - 7ms/step
# Epoch 10/12
# 150/150 - 1s - loss: 0.4388 - categorical_accuracy: 0.8449 - val_loss: 0.5326 - val_categorical_accuracy: 0.8193 - 964ms/epoch - 6ms/step
# Epoch 11/12
# 150/150 - 1s - loss: 0.4261 - categorical_accuracy: 0.8493 - val_loss: 0.5578 - val_categorical_accuracy: 0.8090 - 971ms/epoch - 6ms/step
# Epoch 12/12
# 150/150 - 1s - loss: 0.4085 - categorical_accuracy: 0.8561 - val_loss: 0.5410 - val_categorical_accuracy: 0.8200 - 966ms/epoch - 6ms/step
# Model retrained and saved as log/training_models/best_model_dna_59_retrnd.h5
# Evaluate retrained model on testset ....
# Test Loss: 0.6214, Test Accuracy: 0.7961

# %%
# %run -m python export_model best_model_dna_59_retrnd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_ipython().run_line_magic('run', '-m python export_model best_model_dna_59_retrnd')
#
# File c:\Users\justi\anaconda3\envs\FS25_AAI\lib\site-packages\IPython\core\interactiveshell.py:2417, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2415     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2416 with self.builtin_trap:
# -> 2417     result = fn(*args, **kwargs)
#    2419 # The code below prevents the output from being displayed
#    2420 # when using magics with decodator @output_can_be_silenced
#    2421 # when the last Python token in the expression is a ';'.
#    2422 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\justi\anaconda3\envs\FS25_AAI\lib\site-packages\IPython\core\magics\execution.py:693, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     691 if "m" in opts:
#     692     modulename = opts["m"][0]
# --> 693     modpath = find_mod(modulename)
#     694     if modpath is None:
#     695         msg = '%r is not a valid modulename on sys.path'%modulename
#
# File c:\Users\justi\anaconda3\envs\FS25_AAI\lib\site-packages\IPython\utils\module_paths.py:60, in find_mod(module_name)
#      40 """
#      41 Find module `module_name` on sys.path, and return the path to module `module_name`.
#      42
#    (...)
#      57     depending on above conditions.
#      58 """
#      59 spec = importlib.util.find_spec(module_name)
# ---> 60 module_path = spec.origin
#      61 if module_path is None:
#      62     if spec.loader in sys.meta_path:
#
# AttributeError: 'NoneType' object has no attribute 'origin'
